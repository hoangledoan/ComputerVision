# %% [markdown]
# ## Face detection using OpenCV

# %% [markdown]
# ### Import the libraries

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
image = cv2.imread('D:/ComputerVision/images/multi_faces.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_copy = np.copy(image)
image_copy = cv2.cvtColor(image_copy, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(20,10))
plt.imshow(image_copy, cmap='gray')

# %% [markdown]
# ### Face detection

# %%
#we load in the fully trained architecture of the face detector, 
#found in the file detector_architectures/ haarcascade_frontalface_default.xml,
#and use it on our image to find faces!
face_cascade = cv2.CascadeClassifier('D:\ComputerVision\detector_architectures/haarcascade_frontalface_default.xml')

#scale factor = 4 and minNeighbors = 6
faces = face_cascade.detectMultiScale(image_copy, 4, 6)

# %%
# print out the detections found
print ('We found ' + str(len(faces)) + ' faces in this image')
print ("Their coordinates and lengths/widths are as follows")
print ('=============================')
print (faces)
# Out:
# We found 13 faces in this image
# Their coordinates and lengths/widths are as follows
# =============================
# [[1565  339   96   96]
#  [ 146  458   96   96]
#  [1148  131   96   96]
#  [ 588  390   96   96]
#  [1157  391   96   96]
#  [ 683  149   96   96]
#  [ 771  405   96   96]
#  [1295   94   96   96]
#  [ 510  158   96   96]
#  [ 383  414   96   96]
#  [ 917  102   96   96]
#  [1345  411   96   96]
#  [ 996  526   96   96]]

# %% [markdown]
# ### Plot the image with the face detection

# %%
img_with_detections = np.copy(image)   # make a copy of the original image to plot rectangle detections ontop of

# loop over our detections and draw their corresponding boxes on top of our original image
for (x,y,w,h) in faces:
    # draw next detection as a red rectangle on top of the original image.  
    # Note: the fourth element (255,0,0) determines the color of the rectangle, 
    # and the final argument (here set to 5) determines the width of the drawn rectangle
    cv2.rectangle(img_with_detections,(x,y),(x+w,y+h),(255,0,0),5)  

# display the result
plt.figure(figsize=(20,10))
plt.imshow(img_with_detections)
